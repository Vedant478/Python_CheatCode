# %%
import pandas as pd

# %%
from os import access
mostly used for unstructred data to structured data as per need and as per action
unstrctured data:raw data--data without any specific dimension
                 has all possible info which as per need can be shifted to needed dimension---(parameters)
                 Human---all info
                                --->educational data:degree,score,result
                                --->health:states of organs,blood group,....
                                --->cloths:style,colors,size
                                ---->money:blance,turnover
structured data:data in rows and columns--->limited info ,loss of data,
                                        --->needed info direct access
                                        data base---info--row X columns
                                        lossy:as needed only kept
panda---*.csv     comma separated values---->act as table without any query language needed---No-SQL

# %%
pandas---series(1D),dataframe(2D),3d(n dataframes)
    info of one type,rowsXcolumns,rowsXcolumnsX3:time
n series--->1 data frame------>n Data Frames--->1(time based data frame):Panel

# %%
pip install pandas

# %%
import pandas as pd #using pd shrtform for access

# %%
#series--->made from list data structure
s=pd.Series([11,22,33,44,55])

# %%
print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(s)#direct printable
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
for item in s:#iteratable
    print(item)
# Out:
# 11
# 22
# 33
# 44
# 55

# %%
for i in range(len(s)):#indexed
    print(f"at s[{i}] we have:{s[i]}")
# Out:
# at s[0] we have:11
# at s[1] we have:22
# at s[2] we have:33
# at s[3] we have:44
# at s[4] we have:55

# %%
l=[11,22,33]
l*3
# Out:
# [11, 22, 33, 11, 22, 33, 11, 22, 33]

# %%
series directly operated at element level
print("s*3:",s*3)
# Out:
# s*3: 0     33
# 1     66
# 2     99
# 3    132
# 4    165
# dtype: int64

# %%
s[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-76c3dce40054> in <cell line: 1>()
# ----> 1 s[-1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
min(s)
# Out:
# 11

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ecf9bd7d-7ee8-4c3b-be1d-4acdeca2aec3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecf9bd7d-7ee8-4c3b-be1d-4acdeca2aec3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("emp.csv")
print(df)
# Out:
#             Name  Experience  Salary  Phone Number    Location
# 0   Aarav Sharma           5  750000    9876543210      Mumbai
# 1   Saanvi Patel           3  550000    9123456789   Bangalore
# 2   Vivaan Gupta           8  900000    9988776655       Delhi
# 3     Ananya Rao           4  620000    9234567890   Hyderabad
# 4    Arjun Mehta           6  800000    9345678901     Chennai
# 5     Isha Desai           2  450000    9467890123        Pune
# 6  Reyansh Kumar           7  850000    9123456781   Ahmedabad
# 7     Mira Singh           5  720000    9678901234      Jaipur
# 8   Aakash Verma           9  950000    9898765432     Kolkata
# 9     Kiara Nair           3  580000    9786543210  Coimbatore

# %%
#single data/column  df.<NAME>
df.Name
# Out:
# 0     Aarav Sharma
# 1     Saanvi Patel
# 2     Vivaan Gupta
# 3       Ananya Rao
# 4      Arjun Mehta
# 5       Isha Desai
# 6    Reyansh Kumar
# 7       Mira Singh
# 8     Aakash Verma
# 9       Kiara Nair
# Name: Name, dtype: object

# %%
df[['Name','Salary']]#mutiple column
# Out:
#             Name  Salary
# 0   Aarav Sharma  750000
# 1   Saanvi Patel  550000
# 2   Vivaan Gupta  900000
# 3     Ananya Rao  620000
# 4    Arjun Mehta  800000
# 5     Isha Desai  450000
# 6  Reyansh Kumar  850000
# 7     Mira Singh  720000
# 8   Aakash Verma  950000
# 9     Kiara Nair  580000

# %%
df[['Location','Name','Salary']]#mutiple column
# Out:
#      Location           Name  Salary
# 0      Mumbai   Aarav Sharma  750000
# 1   Bangalore   Saanvi Patel  550000
# 2       Delhi   Vivaan Gupta  900000
# 3   Hyderabad     Ananya Rao  620000
# 4     Chennai    Arjun Mehta  800000
# 5        Pune     Isha Desai  450000
# 6   Ahmedabad  Reyansh Kumar  850000
# 7      Jaipur     Mira Singh  720000
# 8     Kolkata   Aakash Verma  950000
# 9  Coimbatore     Kiara Nair  580000

# %%
df[['Salary']]*0.01
# Out:
#    Salary
# 0  7500.0
# 1  5500.0
# 2  9000.0
# 3  6200.0
# 4  8000.0
# 5  4500.0
# 6  8500.0
# 7  7200.0
# 8  9500.0
# 9  5800.0

# %%
df['Tax']=df.Salary*0.01

# %%
df
# Out:
#             Name  Experience  Salary  Phone Number    Location     Tax
# 0   Aarav Sharma           5  750000    9876543210      Mumbai  7500.0
# 1   Saanvi Patel           3  550000    9123456789   Bangalore  5500.0
# 2   Vivaan Gupta           8  900000    9988776655       Delhi  9000.0
# 3     Ananya Rao           4  620000    9234567890   Hyderabad  6200.0
# 4    Arjun Mehta           6  800000    9345678901     Chennai  8000.0
# 5     Isha Desai           2  450000    9467890123        Pune  4500.0
# 6  Reyansh Kumar           7  850000    9123456781   Ahmedabad  8500.0
# 7     Mira Singh           5  720000    9678901234      Jaipur  7200.0
# 8   Aakash Verma           9  950000    9898765432     Kolkata  9500.0
# 9     Kiara Nair           3  580000    9786543210  Coimbatore  5800.0

# %%
#Net_Salary=Salary-Tax
df['Net_Salary']=df['Salary']-df['Tax']
print(df)
# Out:
#             Name  Experience  Salary  Phone Number    Location     Tax  \
# 0   Aarav Sharma           5  750000    9876543210      Mumbai  7500.0
# 1   Saanvi Patel           3  550000    9123456789   Bangalore  5500.0
# 2   Vivaan Gupta           8  900000    9988776655       Delhi  9000.0
# 3     Ananya Rao           4  620000    9234567890   Hyderabad  6200.0
# 4    Arjun Mehta           6  800000    9345678901     Chennai  8000.0
# 5     Isha Desai           2  450000    9467890123        Pune  4500.0
# 6  Reyansh Kumar           7  850000    9123456781   Ahmedabad  8500.0
# 7     Mira Singh           5  720000    9678901234      Jaipur  7200.0
# 8   Aakash Verma           9  950000    9898765432     Kolkata  9500.0
# 9     Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
#
#    Net_Salary
# 0    742500.0
# 1    544500.0
# 2    891000.0
# 3    613800.0
# 4    792000.0
# 5    445500.0
# 6    841500.0
# 7    712800.0
# 8    940500.0
# 9    574200.0

# %%
len(df)
# Out:
# 10

# %%
#last 5 records/first 5 record
print(df.tail(2))
print(df.head(2))
# Out:
#            Name  Experience  Salary  Phone Number    Location     Tax  \
# 8  Aakash Verma           9  950000    9898765432     Kolkata  9500.0
# 9    Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
#
#    Net_Salary
# 8    940500.0
# 9    574200.0
#            Name  Experience  Salary  Phone Number   Location     Tax  \
# 0  Aarav Sharma           5  750000    9876543210     Mumbai  7500.0
# 1  Saanvi Patel           3  550000    9123456789  Bangalore  5500.0
#
#    Net_Salary
# 0    742500.0
# 1    544500.0

# %%
df.tail(4)
# Out:
#             Name  Experience  Salary  Phone Number    Location     Tax  \
# 6  Reyansh Kumar           7  850000    9123456781   Ahmedabad  8500.0
# 7     Mira Singh           5  720000    9678901234      Jaipur  7200.0
# 8   Aakash Verma           9  950000    9898765432     Kolkata  9500.0
# 9     Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
#
#    Net_Salary
# 6    841500.0
# 7    712800.0
# 8    940500.0
# 9    574200.0

# %%
#list all columns
for column in df:
    print(column)
# Out:
# Name
# Experience
# Salary
# Phone Number
# Location
# Tax
# Net_Salary

# %%
#list each record
for index in range(len(df)):
    print("-"*30)
    print(df.loc[index])
# Out:
# ------------------------------
# Name            Aarav Sharma
# Experience                 5
# Salary                750000
# Phone Number      9876543210
# Location              Mumbai
# Tax                   7500.0
# Net_Salary          742500.0
# Name: 0, dtype: object
# ------------------------------
# Name            Saanvi Patel
# Experience                 3
# Salary                550000
# Phone Number      9123456789
# Location           Bangalore
# Tax                   5500.0
# Net_Salary          544500.0
# Name: 1, dtype: object
# ------------------------------
# Name            Vivaan Gupta
# Experience                 8
# Salary                900000
# Phone Number      9988776655
# Location               Delhi
# Tax                   9000.0
# Net_Salary          891000.0
# Name: 2, dtype: object
# ------------------------------
# Name            Ananya Rao
# Experience               4
# Salary              620000
# Phone Number    9234567890
# ...

# %%
df.loc[::-1]#3 willbe included
# Out:
#             Name  Experience  Salary  Phone Number    Location     Tax  \
# 9     Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
# 8   Aakash Verma           9  950000    9898765432     Kolkata  9500.0
# 7     Mira Singh           5  720000    9678901234      Jaipur  7200.0
# 6  Reyansh Kumar           7  850000    9123456781   Ahmedabad  8500.0
# 5     Isha Desai           2  450000    9467890123        Pune  4500.0
# 4    Arjun Mehta           6  800000    9345678901     Chennai  8000.0
# 3     Ananya Rao           4  620000    9234567890   Hyderabad  6200.0
# 2   Vivaan Gupta           8  900000    9988776655       Delhi  9000.0
# 1   Saanvi Patel           3  550000    9123456789   Bangalore  5500.0
# 0   Aarav Sharma           5  750000    9876543210      Mumbai  7500.0
#
#    Net_Salary
# 9    574200.0
# 8    940500.0
# 7    712800.0
# 6    841500.0
# 5    445500.0
# 4    792000.0
# 3    613800.0
# 2    891000.0
# 1    544500.0
# 0    742500.0

# %%
df.Salary<600000
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9     True
# Name: Salary, dtype: bool

# %%
df[df.Salary<600000]
# Out:
#            Name  Experience  Salary  Phone Number    Location     Tax  \
# 1  Saanvi Patel           3  550000    9123456789   Bangalore  5500.0
# 5    Isha Desai           2  450000    9467890123        Pune  4500.0
# 9    Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
#
#    Net_Salary
# 1    544500.0
# 5    445500.0
# 9    574200.0

# %%
df[df.Experience>5]
# Out:
#             Name  Experience  Salary  Phone Number   Location     Tax  \
# 2   Vivaan Gupta           8  900000    9988776655      Delhi  9000.0
# 4    Arjun Mehta           6  800000    9345678901    Chennai  8000.0
# 6  Reyansh Kumar           7  850000    9123456781  Ahmedabad  8500.0
# 8   Aakash Verma           9  950000    9898765432    Kolkata  9500.0
#
#    Net_Salary
# 2    891000.0
# 4    792000.0
# 6    841500.0
# 8    940500.0

# %%
df[(df.Salary>600000) & (df.Experience<5)]
# Out:
#          Name  Experience  Salary  Phone Number   Location     Tax  Net_Salary
# 3  Ananya Rao           4  620000    9234567890  Hyderabad  6200.0    613800.0

# %%
df[df.Salary==max(df.Salary)]
# Out:
#            Name  Experience  Salary  Phone Number Location     Tax  Net_Salary
# 8  Aakash Verma           9  950000    9898765432  Kolkata  9500.0    940500.0

# %%
df[df.Experience==min(df.Experience)]
# Out:
#          Name  Experience  Salary  Phone Number Location     Tax  Net_Salary
# 5  Isha Desai           2  450000    9467890123     Pune  4500.0    445500.0

# %%
df[df.Salary<sum(df.Salary)/len(df)]
# Out:
#            Name  Experience  Salary  Phone Number    Location     Tax  \
# 1  Saanvi Patel           3  550000    9123456789   Bangalore  5500.0
# 3    Ananya Rao           4  620000    9234567890   Hyderabad  6200.0
# 5    Isha Desai           2  450000    9467890123        Pune  4500.0
# 9    Kiara Nair           3  580000    9786543210  Coimbatore  5800.0
#
#    Net_Salary
# 1    544500.0
# 3    613800.0
# 5    445500.0
# 9    574200.0

# %%
new_df=pd.DataFrame({"Seat_no":[1,2,3,],"Name":["amar","chaman","taman"]})

# %%
new_df
# Out:
#    Seat_no    Name
# 0        1    amar
# 1        2  chaman
# 2        3   taman

# %%
new_df.insert(2,"gender",['m','m','m'])
            location,name,data

# %%
new_df
# Out:
#    Seat_no    Name gender
# 0        1    amar      m
# 1        2  chaman      m
# 2        3   taman      m

# %%
#create new dict with data
df_female=pd.DataFrame({"Seat_no":[4,5,6],"Name":["uma","seema","vilma"],"gender":["f","f","f"]})
print(df_female)
#append to dataframe .append()
new_df=pd.concat([df_female,new_df])
# Out:
#    Seat_no   Name gender
# 0        4    uma      f
# 1        5  seema      f
# 2        6  vilma      f

# %%
print(new_df)
# Out:
#    Seat_no    Name gender
# 0        4     uma      f
# 1        5   seema      f
# 2        6   vilma      f
# 0        1    amar      m
# 1        2  chaman      m
# 2        3   taman      m

# %%
new_df.sort_values(['Seat_no'])
# Out:
#    Seat_no    Name gender
# 0        1    amar      m
# 1        2  chaman      m
# 2        3   taman      m
# 0        4     uma      f
# 1        5   seema      f
# 2        6   vilma      f
